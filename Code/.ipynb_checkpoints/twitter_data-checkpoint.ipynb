# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\bharg\appdata\local\temp\pip-req-build-it3i1j8l
# Requirement already satisfied: requests[socks] in c:\users\bharg\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (2.26.0)
# Requirement already satisfied: lxml in c:\users\bharg\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (4.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\bharg\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (4.9.3)
# Requirement already satisfied: pytz in c:\users\bharg\anaconda3\lib\site-packages (from snscrape==0.3.5.dev139+g35fb61a) (2021.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bharg\anaconda3\lib\site-packages (from beautifulsoup4->snscrape==0.3.5.dev139+g35fb61a) (2.2.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bharg\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bharg\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bharg\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bharg\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (1.26.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\bharg\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev139+g35fb61a) (1.7.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (setup.py): started
#   Building wheel for snscrape (setup.py): finished with status 'done'
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev139+g35fb61a-py3-none-any.whl size=52219 sha256=1f2b7f85967d5caa5c0de03b04cf9b281345c09363e5738c0b435d754e95e631
#   Stored in directory: C:\Users\bharg\AppData\Local\Temp\pip-ephem-wheel-cache-y_98i4_j\wheels\92\42\87\33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# Installing collected packages: snscrape
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.3.5.dev138+ga6b6f3f
#     Uninstalling snscrape-0.3.5.dev138+ga6b6f3f:
#       Successfully uninstalled snscrape-0.3.5.dev138+ga6b6f3f
# Successfully installed snscrape-0.3.5.dev139+g35fb61a
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\bharg\AppData\Local\Temp\pip-req-build-it3i1j8l'

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
celebs =[ 'theweeknd', 'aliwong', 'michaelb4jordan','selenagomez', 'JBALVIN', 'itsjojosiwa', 'halsey', 'IAMJHUD',
'YoYo_Ma', 'DapperDanHarlem','anaismitchell', 'MichaelaCoel' , 'JulieMehretu', 'ayushmannk', 'VP', 'iingwen',
'johnrobertsFox', 'POTUS', 'jairbolsonaro', 'SpeakerPelosi', 'narendramodi' , 'Anne_Hidalgo', 'DrTedros',
'MaryKayHenry', 'vonderleyen', 'NNUBonnie', 'MTamfum', 'Giannis_An34', 'DrIbram', 'nathanlawkc', 'Astro_Christina', 'jkbjournalist',
'MooreMaya', 'chasestrangio', 'tourmaliiine', 'waadalkateab',
'g_camara_b', 'camilla_rothe', 'rebeccagomperts', 'ravgup33_ravi', 'TexasDownUnder', 'photograshiori', 'theestallion']
# Creating list to append tweet data to
tweets_list1 = []
?
# Using TwitterSearchScraper to scrape data and append tweets to list
for name in celebs:
    data = 'from:'+name+ ' since:2019-01-01 until:2019-12-31'
    print(data)
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(data).get_items()):
        if i>1000:
            break
        if (tweet.retweetCount)>20:
            tweets_list1.append([tweet.user.displayname,tweet.user.followersCount,tweet.user.created,tweet.likeCount,
tweet.user,tweet.content,tweet.retweetCount,tweet.user.location])
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Name','Number of Followers','Account created Date','Number of Likes',
'TwitterHandle','Content','RetweetCount','Location'])
tweets_df1
# Out:
# from:theweeknd since:2019-01-01 until:2019-12-31
# from:aliwong since:2019-01-01 until:2019-12-31
# from:michaelb4jordan since:2019-01-01 until:2019-12-31
# from:selenagomez since:2019-01-01 until:2019-12-31
# from:JBALVIN since:2019-01-01 until:2019-12-31
# from:itsjojosiwa since:2019-01-01 until:2019-12-31
# from:halsey since:2019-01-01 until:2019-12-31
# from:IAMJHUD since:2019-01-01 until:2019-12-31
# from:YoYo_Ma since:2019-01-01 until:2019-12-31
# from:DapperDanHarlem since:2019-01-01 until:2019-12-31
# from:anaismitchell since:2019-01-01 until:2019-12-31
# from:MichaelaCoel since:2019-01-01 until:2019-12-31
# from:JulieMehretu since:2019-01-01 until:2019-12-31
# from:ayushmannk since:2019-01-01 until:2019-12-31
# from:VP since:2019-01-01 until:2019-12-31
# from:iingwen since:2019-01-01 until:2019-12-31
# from:johnrobertsFox since:2019-01-01 until:2019-12-31
# from:POTUS since:2019-01-01 until:2019-12-31
# from:jairbolsonaro since:2019-01-01 until:2019-12-31
# from:SpeakerPelosi since:2019-01-01 until:2019-12-31
# from:narendramodi since:2019-01-01 until:2019-12-31
# from:Anne_Hidalgo since:2019-01-01 until:2019-12-31
# from:DrTedros since:2019-01-01 until:2019-12-31
# from:MaryKayHenry since:2019-01-01 until:2019-12-31
# from:vonderleyen since:2019-01-01 until:2019-12-31
# from:NNUBonnie since:2019-01-01 until:2019-12-31
# from:MTamfum since:2019-01-01 until:2019-12-31
# from:Giannis_An34 since:2019-01-01 until:2019-12-31
# from:DrIbram since:2019-01-01 until:2019-12-31
# from:nathanlawkc since:2019-01-01 until:2019-12-31
# from:Astro_Christina since:2019-01-01 until:2019-12-31
# from:jkbjournalist since:2019-01-01 until:2019-12-31
# from:MooreMaya since:2019-01-01 until:2019-12-31
# from:chasestrangio since:2019-01-01 until:2019-12-31
# from:tourmaliiine since:2019-01-01 until:2019-12-31
# from:waadalkateab since:2019-01-01 until:2019-12-31
# from:g_camara_b since:2019-01-01 until:2019-12-31
# from:camilla_rothe since:2019-01-01 until:2019-12-31
# from:rebeccagomperts since:2019-01-01 until:2019-12-31
# from:ravgup33_ravi since:2019-01-01 until:2019-12-31
# from:TexasDownUnder since:2019-01-01 until:2019-12-31
# from:photograshiori since:2019-01-01 until:2019-12-31
# from:theestallion since:2019-01-01 until:2019-12-31
#              Name  Number of Followers      Account created Date  \
# 0      The Weeknd             15280939 2011-02-21 07:45:45+00:00
# 1      The Weeknd             15280939 2011-02-21 07:45:45+00:00
# 2      The Weeknd             15280939 2011-02-21 07:45:45+00:00
# 3      The Weeknd             15280939 2011-02-21 07:45:45+00:00
# 4      The Weeknd             15280939 2011-02-21 07:45:45+00:00
# ...           ...                  ...                       ...
# 11789   TINA SNOW              7240610 2010-01-12 02:17:58+00:00
# 11790   TINA SNOW              7240610 2010-01-12 02:17:58+00:00
# 11791   TINA SNOW              7240610 2010-01-12 02:17:58+00:00
# 11792   TINA SNOW              7240610 2010-01-12 02:17:58+00:00
# 11793   TINA SNOW              7240610 2010-01-12 02:17:58+00:00
#
#        Number of Likes                     TwitterHandle  \
# 0                62346     https://twitter.com/theweeknd
# 1                19990     https://twitter.com/theweeknd
# 2                43717     https://twitter.com/theweeknd
# 3                16891     https://twitter.com/theweeknd
# 4                12969     https://twitter.com/theweeknd
# ...                ...                               ...
# 11789              354  https://twitter.com/theestallion
# 11790             6217  https://twitter.com/theestallion
# 11791             2703  https://twitter.com/theestallion
# 11792            10470  https://twitter.com/theestallion
# 11793            20260  https://twitter.com/theestallion
#
#                                                  Content  RetweetCount  \
# 0      let’s keep them coming. XO https://t.co/ftYg9Y...          7022
# 1      you’re not wrong. must have been subconscious....          1372
# 2      ya’ll really turned this into a GIF 🤣 https://...          4947
# 3           i went full method ! https://t.co/AvJBsz8GCf          1347
# 4                     ‼️‼️‼️‼️‼️ https://t.co/6uYWWJuqSI          1051
# ...                                                  ...           ...
# 11789  Let me do some research cuz I need that 😍 http...            34
# 11790  HOTGIRL Pajama party Recap🔥 https://t.co/UmeTB...          1538
# 11791                        😂😂😂 https://t.co/IABUgjk3S4           638
# 11792          Good morning LA☀️ https://t.co/TwUoyusJ5z          1501
# 11793  Oh shit I’m verified on Twitter now https://t....          2668
#
#                Location
# 0      Toronto, Ontario
# 1      Toronto, Ontario
# 2      Toronto, Ontario
# 3      Toronto, Ontario
# 4      Toronto, Ontario
# ...                 ...
# 11789               HTX
# 11790               HTX
# 11791               HTX
# 11792               HTX
# 11793               HTX
#
# [11794 rows x 8 columns]

# %%
tweets_df1["TwitterHandle"].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24216/3644153867.py in <module>
# ----> 1 tweets_df1.TwitterHandle.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    2037         Categories (3, object): ['a' < 'b' < 'c']
#    2038         """
# -> 2039         return super().unique()
#    2040
#    2041     @overload
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#     977                     result = np.asarray(result)
#     978         else:
# --> 979             result = unique1d(values)
#     980
#     981         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     429
#     430     table = htable(len(values))
# --> 431     uniques = table.unique(values)
#     432     uniques = _reconstruct_data(uniques, original.dtype, original)
#     433     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'User'

# %%
, 'aliwong', 
 'JulieMehretu',  
'g_camara_b', 'camilla_rothe', 'rebeccagomperts', 'ravgup33_ravi', 'TexasDownUnder', 'photograshiori', 'theestallion']

# %%
tweets_df1.to_csv('twitter_data.csv')
